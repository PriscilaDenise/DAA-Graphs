# %% [markdown]
# ### GROUP MEMBERS
# 1. Muwanguzi Priscila Denise M23B23/010
# 2. Nicole Johnson  S23B23/020
# 3. Mawejje JohnPaul M23B23/049

# %%
import random
import time
import matplotlib.pyplot as plt

# Bubble Sort
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

# Insertion Sort
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

# Merge Sort
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]

        merge_sort(L)
        merge_sort(R)

        i = j = k = 0
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1

# Quick Sort
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# Selection Sort
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]

# Measure execution time for an algorithm
def measure_time(algorithm, data):
    start_time = time.time()
    algorithm(data)
    end_time = time.time()
    return end_time - start_time

# List sizes for testing
list_sizes = [100, 500, 1000, 2000, 5000]
times = {
    "Bubble Sort": [],
    "Insertion Sort": [],
    "Merge Sort": [],
    "Quick Sort": [],
    "Selection Sort": []
}

# Collect execution time data for each algorithm and list size
for size in list_sizes:
    data = random.sample(range(size * 10), size)

    # Bubble Sort
    bubble_data = data[:]
    times["Bubble Sort"].append(measure_time(bubble_sort, bubble_data))

    # Insertion Sort
    insertion_data = data[:]
    times["Insertion Sort"].append(measure_time(insertion_sort, insertion_data))

    # Merge Sort
    merge_data = data[:]
    times["Merge Sort"].append(measure_time(merge_sort, merge_data))

    # Quick Sort
    quick_data = data[:]
    times["Quick Sort"].append(measure_time(quick_sort, quick_data))

    # Selection Sort
    selection_data = data[:]
    times["Selection Sort"].append(measure_time(selection_sort, selection_data))

# Plot the results
plt.figure(figsize=(10, 6))
for algorithm, time_taken in times.items():
    plt.plot(list_sizes, time_taken, label=algorithm)

plt.title("Time Complexity Comparison of Sorting Algorithms")
plt.xlabel("List Size")
plt.ylabel("Time (seconds)")
plt.legend()
plt.grid()
plt.show()
